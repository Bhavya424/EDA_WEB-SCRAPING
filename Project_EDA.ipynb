# %% [markdown]
# # Introduction & Data Source
# This project scrapes NBA player data from Basketball Reference and performs Exploratory Data Analysis (EDA).

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Web Scraping

# %%
url = "https://www.basketball-reference.com/players/b/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/117.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
}

# %%
response = requests.get(url, headers=headers)

print(response.status_code)   # should be 200 if allowed
print(response.text[:100])   # show first 1000 chars of HTML
# Out:
# 200
#
# <!DOCTYPE html>
# <html data-version="klecko-" data-root="/home/bbr/build" lang="en" class="no-js" >

# %%
url = "https://www.basketball-reference.com/players/b/"
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, "html.parser")
table = soup.find('table', {'id': 'players'})

# %%
def height_to_inches(height_str):
    if height_str and '-' in height_str:
        feet, inches = height_str.split('-')
        return int(feet) * 12 + int(inches)
    return None

# %%
players_data = []

if table:
    rows = table.tbody.find_all('tr')
    for row in rows:
        player_name = row.find('th', {'data-stat': 'player'}).text.strip()
        colleges = row.find('td', {'data-stat': 'colleges'}).text.strip() if row.find('td', {'data-stat': 'colleges'}) else ''
        birth_date = row.find('td', {'data-stat': 'birth_date'}).text.strip() if row.find('td', {'data-stat': 'birth_date'}) else ''
        weight_str = row.find('td', {'data-stat': 'weight'}).text.strip() if row.find('td', {'data-stat': 'weight'}) else ''
        height_str = row.find('td', {'data-stat': 'height'}).text.strip() if row.find('td', {'data-stat': 'height'}) else ''
        position = row.find('td', {'data-stat': 'pos'}).text.strip() if row.find('td', {'data-stat': 'pos'}) else ''
        year_from_str = row.find('td', {'data-stat': 'year_min'}).text.strip() if row.find('td', {'data-stat': 'year_min'}) else ''
        year_to_str = row.find('td', {'data-stat': 'year_max'}).text.strip() if row.find('td', {'data-stat': 'year_max'}) else ''

        # Convert height string like "6-7" to total inches integer
        height = height_to_inches(height_str)

        # Convert weight and years to integers where possible
        weight = int(weight_str) if weight_str.isdigit() else None
        year_from = int(year_from_str) if year_from_str.isdigit() else None
        year_to = int(year_to_str) if year_to_str.isdigit() else None

        players_data.append({
            'Player': player_name,
            'Colleges': colleges,
            'Birth Date': birth_date,
            'Weight': weight,
            'Height': height,
            'Position': position,
            'From Year': year_from,
            'To Year': year_to
        })

# %%
# Create DataFrame
df = pd.DataFrame(players_data)

print(df.head())
# Out:
#          Player                            Colleges         Birth Date  \
# 0    Chris Babb              Penn State, Iowa State  February 14, 1990
# 1  Luke Babbitt                              Nevada      June 20, 1989
# 2   Miloš Babić  Tennessee Technological University  November 23, 1968
# 3   Johnny Bach                             Fordham      July 10, 1924
# 4  Dwayne Bacon                       Florida State    August 30, 1995
#
#    Weight  Height Position  From Year  To Year
# 0     225      77        G       2014     2014
# 1     225      81        F       2011     2018
# 2     240      84      C-F       1991     1992
# 3     180      74      F-G       1949     1949
# 4     221      78        G       2018     2021

# %%
df.to_csv('players_data.csv', index=False)

# %% [markdown]
# ## Data Cleaning & Preparation

# %%
def height_to_inches(height_str):
    if height_str and '-' in height_str:
        feet, inches = height_str.split('-')
        return int(feet) * 12 + int(inches)
    return None

# %%
df.head()
# Out:
#          Player                            Colleges         Birth Date  \
# 0    Chris Babb              Penn State, Iowa State  February 14, 1990
# 1  Luke Babbitt                              Nevada      June 20, 1989
# 2   Miloš Babić  Tennessee Technological University  November 23, 1968
# 3   Johnny Bach                             Fordham      July 10, 1924
# 4  Dwayne Bacon                       Florida State    August 30, 1995
#
#    Weight  Height Position  From Year  To Year
# 0     225      77        G       2014     2014
# 1     225      81        F       2011     2018
# 2     240      84      C-F       1991     1992
# 3     180      74      F-G       1949     1949
# 4     221      78        G       2018     2021

# %%
df.size # rows X columns
# Out:
# 4064

# %%
df.shape
# Out:
# (508, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Player        0
# Colleges      0
# Birth Date    0
# Weight        0
# Height        0
# Position      0
# From Year     0
# To Year       0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of               Player                            Colleges         Birth Date  \
# 0         Chris Babb              Penn State, Iowa State  February 14, 1990
# 1       Luke Babbitt                              Nevada      June 20, 1989
# 2        Miloš Babić  Tennessee Technological University  November 23, 1968
# 3        Johnny Bach                             Fordham      July 10, 1924
# 4       Dwayne Bacon                       Florida State    August 30, 1995
# ..               ...                                 ...                ...
# 503       Will Bynum               Arizona, Georgia Tech    January 4, 1983
# 504        Walt Byrd                              Temple
# 505     Marty Byrnes                            Syracuse     April 30, 1956
# 506     Tommy Byrnes                          Seton Hall  February 19, 1923
# 507  Michael Bytzura              Long Island University      June 18, 1922
#
#      Weight  Height Position  From Year  To Year
# 0       225      77        G       2014     2014
# 1       225      81        F       2011     2018
# 2       240      84      C-F       1991     1992
# 3       180      74      F-G       1949     1949
# 4       221      78        G       2018     2021
# ..      ...     ...      ...        ...      ...
# 503     185      72        G       2006     2015
# 504     205      79        F       1970     1970
# 505     215      79        F       1979     1983
# 506     175      75      F-G       1947     1951
# 507     170      73        F       1947     1947
#
# [508 rows x 8 columns]>

# %%
df.describe()
# Out:
#            Weight      Height    From Year      To Year
# count  508.000000  508.000000   508.000000   508.000000
# mean   208.342520   78.011811  1990.669291  1994.974409
# std     25.568271    3.647681    23.328900    24.130344
# min    135.000000   63.000000  1947.000000  1947.000000
# 25%    190.000000   76.000000  1972.750000  1976.000000
# 50%    208.000000   78.000000  1993.000000  1999.000000
# 75%    225.000000   80.250000  2012.000000  2018.000000
# max    360.000000   91.000000  2025.000000  2025.000000

# %% [markdown]
# ## Univariate Analysis

# %%
df.dtypes
# Out:
# Player        object
# Colleges      object
# Birth Date    object
# Weight         int64
# Height         int64
# Position      object
# From Year      int64
# To Year        int64
# dtype: object

# %%
num_df = df.select_dtypes(include=["int64", "float64"])
print("Numerical data:\n")
print(num_df.dtypes)
# Out:
# Numerical data:
#
# Weight       int64
# Height       int64
# From Year    int64
# To Year      int64
# dtype: object

# %%
cat_df = df.select_dtypes(include=["object"])
print("Categorical data:\n")
print(cat_df.dtypes)
# Out:
# Categorical data:
#
# Player        object
# Colleges      object
# Birth Date    object
# Position      object
# dtype: object

# %%
print(df['Colleges'].value_counts())
# Out:
# Colleges
#                             40
# UCLA                        12
# Kentucky                    10
# UNC                          9
# Oregon                       8
#                             ..
# Assumption University        1
# North Carolina A&T           1
# Pitt, UNLV                   1
# Indiana State University     1
# Arizona, Georgia Tech        1
# Name: count, Length: 227, dtype: int64

# %%
print(df['Position'].value_counts())
# Out:
# Position
# G      184
# F      145
# C       57
# F-C     41
# G-F     37
# F-G     26
# C-F     18
# Name: count, dtype: int64

# %%
df['Player'].value_counts()
# Out:
# Player
# Dee Brown          2
# Chris Babb         1
# Mike Bratz         1
# Ronnie Brewer      1
# Ron Brewer         1
#                   ..
# Ben Bentil         1
# Kent Benson        1
# Keith Benson       1
# David Benoit       1
# Michael Bytzura    1
# Name: count, Length: 507, dtype: int64

# %%
df['Birth Date'].value_counts()
# Out:
# Birth Date
# August 31, 1952      2
# August 26, 1947      2
# December 3, 1951     2
# November 20, 1975    2
# November 12, 1992    2
#                     ..
# March 29, 1995       1
# December 27, 1954    1
# August 13, 1988      1
# May 9, 1968          1
# June 18, 1922        1
# Name: count, Length: 503, dtype: int64

# %%
df['CareerLength'] = df['To Year'] - df['From Year']

# %% [markdown]
# ## Univariate Analysis : Numerical Data

# %%
# Height Distribution
plt.hist(df['Height'].dropna(), bins=20, edgecolor='black',color='skyblue')
plt.title('Distribution of Player Heights')
plt.xlabel('Height (inches)')
plt.ylabel('Frequency')
plt.show()

sns.boxplot(y=df['Height'].dropna())
plt.title('Box plot of player heights')
plt.ylabel('Height (inches)')
plt.show()

# Weight Distribution
plt.hist(df['Weight'].dropna(), bins=20, edgecolor='black',color='lightgreen')
plt.title('Distribution of Player Weights')
plt.xlabel('Weight (lbs)')
plt.ylabel('Frequency')
plt.show()

sns.boxplot(y=df['Weight'].dropna())
plt.title('Box plot of player weights')
plt.ylabel('Weight (lbs)')
plt.show()

# Career Length Distribution
plt.hist(df['CareerLength'].dropna(), bins=20, edgecolor='black',color='salmon')
plt.title('Distribution of Career Lengths')
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Univariate Analysis -Categorical Data

# %%
# Position counts
print(df['Position'].value_counts())

sns.countplot(x='Position', data=df, order=df['Position'].value_counts().index)
plt.title('Number of Players by Position')
plt.xlabel('Position')
plt.ylabel('Count')
plt.show()

# Top Colleges by player counts
top_colleges = df['Colleges'].value_counts().head(10)
print(top_colleges)

top_colleges.plot(kind='bar')
plt.title('Top 10 Colleges by Players in NBA')
plt.xlabel('College')
plt.ylabel('Number of Players')
plt.show()
# Out:
# Position
# G      184
# F      145
# C       57
# F-C     41
# G-F     37
# F-G     26
# C-F     18
# Name: count, dtype: int64
# Colleges
#              40
# UCLA         12
# Kentucky     10
# UNC           9
# Oregon        8
# Temple        8
# Duke          8
# NC State      8
# Minnesota     7
# Michigan      6
# Name: count, dtype: int64

# %% [markdown]
# ## Bivaraite Analysis or Multivariate Analysis

# %% [markdown]
# ### 1. Scatter Plot: Height vs Weight (colored by Position)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Height', y='Weight', hue='Position', data=df)
plt.title('Height vs Weight')
plt.xlabel('Height (inches)')
plt.ylabel('Weight (lbs)')
plt.show()

# %% [markdown]
# #### In basketball,
# * G typically refers to guards (Point Guard and Shooting Guard),
# * F refers to forwards (Small Forward and Power Forward),
# * C is the Center,
# * Point Guard (PG) initiating plays and the Center (C).

# %% [markdown]
# ### 2. Boxplots by Position

# %%
sns.boxplot(x='Position', y='Height', data=df)
plt.title('Box plot of player heights by position')
plt.xlabel('Position')
plt.ylabel('Height (inches)')
plt.show()

sns.boxplot(x='Position', y='Weight', data=df)
plt.title('Box plot of player weights by position')
plt.xlabel('Position')
plt.ylabel('Weight (lbs)')
plt.show()

# %% [markdown]
# ### 3. Correlation Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[['Height', 'Weight', 'CareerLength']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### 4. Grouped Analysis

# %%
# Average stats by position
avg_by_position = df.groupby('Position').agg(
    avg_height=('Height', 'mean'),
    avg_weight=('Weight', 'mean'),
    avg_career_length=('CareerLength', 'mean')
).reset_index()
print(avg_by_position)

# Median, max, min height by position
height_stats = df.groupby('Position')['Height'].agg(['mean', 'median', 'max', 'min']).reset_index()
print(height_stats)

# Players born after 1990 grouped by position
df['Birth year'] = pd.to_datetime(df['Birth Date']).dt.year
young_players_by_pos = df[df['Birth year'] > 1990].groupby('Position').size().reset_index(name='count')
print(young_players_by_pos)
# Out:
#   Position  avg_height  avg_weight  avg_career_length
# 0        C   83.456140  237.894737           4.105263
# 1      C-F   81.333333  232.944444           4.722222
# 2        F   79.020690  215.896552           3.186207
# 3      F-C   80.878049  226.341463           6.365854
# 4      F-G   77.692308  204.923077           6.692308
# 5        G   74.744565  188.614130           4.038043
# 6      G-F   77.351351  201.810811           6.162162
#   Position       mean  median  max  min
# 0        C  83.456140    83.0   91   79
# 1      C-F  81.333333    81.0   85   78
# 2        F  79.020690    79.0   84   73
# 3      F-C  80.878049    81.0   87   77
# 4      F-G  77.692308    78.0   81   74
# 5        G  74.744565    75.0   82   63
# 6      G-F  77.351351    77.0   81   71
#   Position  count
# 0        C     10
# 1      C-F      3
# 2        F     34
# 3      F-C      4
# 4      F-G      4
# 5        G     45
# 6      G-F     13

# %% [markdown]
# ### 5. Recruitment Trends

# %%
# Players recruited per college per "from year"
college_recruitment = df.groupby(['Colleges', 'From Year']).size().reset_index(name='playercount')
print(college_recruitment.head())

# Number of players recruited each year
yearly_recruitment = df.groupby('From Year').size().reset_index(name='playersrecruited')
print(yearly_recruitment)

# Group by colleges and positions
college_pos_counts = df.groupby(['Colleges', 'Position']).size().reset_index(name='count')
print(college_pos_counts.head())

# Top colleges by number of players recruited
top_colleges = college_recruitment.groupby('Colleges')['playercount'].sum().sort_values(ascending=False).head(10)
print(top_colleges)
# Out:
#   Colleges  From Year  playercount
# 0                1947            1
# 1                1948            1
# 2                1949            1
# 3                1995            1
# 4                1997            2
#     From Year  playersrecruited
# 0        1947                13
# 1        1948                 3
# 2        1949                 9
# 3        1950                13
# 4        1951                 4
# ..        ...               ...
# 73       2021                 8
# 74       2022                12
# 75       2023                10
# 76       2024                10
# 77       2025                 8
#
# [78 rows x 2 columns]
#   Colleges Position  count
# 0                 C      8
# 1               C-F      2
# 2                 F     14
# 3               F-C      3
# 4               F-G      1
# Colleges
#              40
# UCLA         12
# Kentucky     10
# UNC           9
# Temple        8
# Duke          8
# Oregon        8
# NC State      8
# Minnesota     7
# UConn         6
# Name: playercount, dtype: int64

# %%
df['CareerLength'] = df['To Year'] - df['From Year']
df['From Year Date'] = pd.to_datetime(df['From Year'].astype(str) + '-01-01')
df = df.set_index('From Year Date')
avg_career_length = df.resample('YE')['CareerLength'].mean()
avg_career_length.plot(figsize=(12,6))
plt.title('Average NBA Career Length by Starting Year')
plt.xlabel('Year')
plt.ylabel('Average Career Length (years)')
plt.show()

# %%
import numpy as np

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower) | (data[column] > upper)]
    return outliers

# Detect outliers for height, weight, career length
outliers_height = detect_outliers_iqr(df, 'Height')
outliers_weight = detect_outliers_iqr(df, 'Weight')
outliers_career = detect_outliers_iqr(df, 'CareerLength')

print("Height outliers:", outliers_height[['Player', 'Height']].head())
print("Weight outliers:", outliers_weight[['Player', 'Weight']].head())
print("Career Length outliers:", outliers_career[['Player', 'CareerLength']].head())
# Out:
# Height outliers:                        Player  Height
# From Year Date
# 2015-01-01        Sim Bhullar      89
# 1988-01-01      Muggsy Bogues      63
# 2020-01-01            Bol Bol      87
# 1986-01-01         Manute Bol      91
# 1999-01-01       Earl Boykins      65
# Weight outliers:                        Player  Weight
# From Year Date
# 2002-01-01      Mengke Bateer     290
# 2015-01-01        Sim Bhullar     360
# 1988-01-01      Muggsy Bogues     136
# 1999-01-01       Earl Boykins     135
# 2006-01-01       Andrew Bynum     285
# Career Length outliers: Empty DataFrame
# Columns: [Player, CareerLength]
# Index: []

# %%
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    cleaned_data = data[(data[column] >= lower) & (data[column] <= upper)]
    return cleaned_data

# Remove outliers separately
df_height_clean = remove_outliers_iqr(df, 'Height')
df_weight_clean = remove_outliers_iqr(df, 'Weight')
df_career_clean = remove_outliers_iqr(df, 'CareerLength')

print("Original data shape:", df.shape)
print("After removing height outliers:", df_height_clean.shape)
print("After removing weight outliers:", df_weight_clean.shape)
print("After removing career length outliers:", df_career_clean.shape)
# Out:
# Original data shape: (508, 11)
# After removing height outliers: (500, 11)
# After removing weight outliers: (503, 11)
# After removing career length outliers: (508, 11)

# %%
df['age at career start']=df['From Year']-df['Birth year']

# %%
import matplotlib.pyplot as plt

plt.hist(df['age at career start'].dropna(), bins=15, color='purple', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Player')
plt.show()

# %% [markdown]
# ## Key Insights
# - Height & Weight are strongly correlated.
# - Centers (C) tend to be the tallest and heaviest.
# - Guards (G) are generally shorter and lighter.
# - Most careers last less than 10 years, though some exceed 15.
# - Certain colleges dominate NBA recruitment (Duke, Kentucky).
# - Recruitment trends vary significantly by year.
